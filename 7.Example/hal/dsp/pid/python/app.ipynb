# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("output.txt",sep='\t',header=None)

# %%
vol = np.array(data[0]) # 电压值
pid = np.array(data[1]) # DAC值(12bit) / PID值
adc = np.array(data[2]) # ADC值(12bit)

# %%
plt.figure(figsize=(15,6))  
plt.plot(vol) # 当前输出电压值
plt.plot([2.15809]*len(vol)) # 目标输出电压值
plt.show()

# %%
plt.figure(figsize=(15,6))  
plt.plot(pid)
plt.plot(adc)
plt.show()
